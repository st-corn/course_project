# %%
#!pip uninstall torch torchvision torchaudio -y
#!pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
#!nvcc --version

# %%
import time
import torch
import torch.nn as nn
import numpy as np
import random
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
from torch.autograd import grad
import warnings
warnings.filterwarnings('ignore')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Устройство: {device}")
# Out:
# Устройство: cuda

# %% [markdown]
# Фиксация сида для воспроизводимости эксперимента.

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# Выбор параметры дифференциального уравнения, аналитическое решение уравнения.

# %%
beta = 30.0
x_min, x_max = 0.0, 2.0 * np.pi
t_min, t_max = 0.0, 0.2

x_scale = x_max - x_min
t_scale = t_max - t_min

def analytical_solution(x, t):
    return torch.sin(x - beta * t)

# %% [markdown]
# Класс модели: четыре линейных слоя и три нелинейных, использующих гиперболический тангенс.

# %%
class PINN(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(2, 256),
            nn.Tanh(),
            nn.Linear(256, 256),
            nn.Tanh(),
            nn.Linear(256, 256),
            nn.Tanh(),
            nn.Linear(256, 1)
        )
        self.init_weights()

    def init_weights(self):
        def init_weights_layer(m):
            if type(m) == nn.Linear:
                torch.nn.init.xavier_uniform_(m.weight)
                m.bias.data.fill_(0.0)

        self.model.apply(init_weights_layer)

    def forward(self, x, t):
        inp = torch.cat([x, t], dim=1)
        return self.model(inp)

# %%
class BIGPINN(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(2, 256),
            nn.Tanh(),
            nn.Linear(256, 256),
            nn.Tanh(),
            nn.Linear(256, 256),
            nn.Tanh(),
            nn.Linear(256, 256),
            nn.Tanh(),
            nn.Linear(256, 1)
        )
        self.init_weights()

    def init_weights(self):
        def init_weights_layer(m):
            if type(m) == nn.Linear:
                torch.nn.init.xavier_uniform_(m.weight)
                m.bias.data.fill_(0.0)

        self.model.apply(init_weights_layer)

    def forward(self, x, t):
        inp = torch.cat([x, t], dim=1)
        return self.model(inp)

# %%
class PeriodicPINN(nn.Module):
    def __init__(self):
        super().__init__()
        self.feature_extractor = None

        self.model = nn.Sequential(
            nn.Linear(6, 128),
            nn.Tanh(),
            nn.Linear(128, 128),
            nn.Tanh(),
            nn.Linear(128, 128),
            nn.Tanh(),
            nn.Linear(128, 1)
        )
        self.init_weights()

    def init_weights(self):
        def init_weights_layer(m):
            if type(m) == nn.Linear:
                torch.nn.init.xavier_uniform_(m.weight)
                m.bias.data.fill_(0.0)
        self.model.apply(init_weights_layer)

    def forward(self, x, t):
        inp = torch.cat([x, t], dim=1)
        two_pi = 2 * torch.pi
        sin_x = torch.sin(two_pi * x)
        cos_x = torch.cos(two_pi * x)
        sin_t = torch.sin(two_pi * t)
        cos_t = torch.cos(two_pi * t)
        features = torch.cat([inp, sin_x, cos_x, sin_t, cos_t], dim=1)
        return self.model(features)

# %% [markdown]
# Функции для вычисления невязки дифференциального уравнения и общих потерь. Веса для трех частей, из которых состоят потери, были подобраны в ходе экспериментов.

# %%
def pde_residual(model, x_norm, t_norm, beta, x_scale, t_scale):
    x_norm.requires_grad_(True)
    t_norm.requires_grad_(True)

    u = model(x_norm, t_norm)

    u_t_norm = grad(u, t_norm, grad_outputs=torch.ones_like(u), create_graph=True)[0]
    u_x_norm = grad(u, x_norm, grad_outputs=torch.ones_like(u), create_graph=True)[0]

    u_t = u_t_norm / t_scale
    u_x = u_x_norm / x_scale

    return u_t + beta * u_x

def compute_loss(model, points, beta, x_scale, t_scale, weights=(1.0, 50.0, 50.0)):
    w_pde, w_ic, w_bc = weights
    x_res, t_res = points['pde']

    # PDE residual loss - невязка дифференциального уравнения в частных производных
    loss_pde = torch.mean(pde_residual(model, x_res, t_res, beta, x_scale, t_scale)**2)

    # IC loss - потери, связанные с начальным условием
    x_ic, t_ic, u_ic = points['ic']
    u_ic_pred = model(x_ic, t_ic)
    loss_ic = torch.mean((u_ic_pred - u_ic)**2)

    # BC loss - потери, связанные с граничным условием
    x_l, t_l, x_r, t_r = points['bc']
    u_l = model(x_l, t_l)
    u_r = model(x_r, t_r)
    loss_bc = torch.mean((u_l - u_r)**2)

    total = w_pde * loss_pde + w_ic * loss_ic + w_bc * loss_bc
    return total / (w_pde + w_ic + w_bc), loss_pde, loss_ic, loss_bc

# %% [markdown]
# Функция, генерирующая набор точек: удовлетворяющих начальному условию, удовлетворяюзих граничному условию, и прочих.

# %%
def train(model, points, beta, dtype, device, x_scale, t_scale, epochs_adam=1000, epochs_lbfgs=0,
          lr=1e-3, clipping_on=False, epoch_log_adam=500, epoch_log_lbfgs=100, compare_loss=False):
    model = model.to(dtype).to(device)
    points_dtype = {}
    points_dtype['pde'] = (points['pde'][0].to(dtype).to(device), points['pde'][1].to(dtype).to(device))
    points_dtype['ic'] = (points['ic'][0].to(dtype).to(device), points['ic'][1].to(dtype).to(device), points['ic'][2].to(dtype).to(device))
    points_dtype['bc'] = (points['bc'][0].to(dtype).to(device), points['bc'][1].to(dtype).to(device),
                          points['bc'][2].to(dtype).to(device), points['bc'][3].to(dtype).to(device))

    with torch.no_grad():
        x_val = torch.linspace(0, 1, 100).reshape(-1, 1).to(dtype).to(device)
        t_val = torch.linspace(0, 1, 100).reshape(-1, 1).to(dtype).to(device)
        X_val, T_val = torch.meshgrid(x_val.squeeze(), t_val.squeeze(), indexing='ij')
        X_flat = X_val.reshape(-1, 1)
        T_flat = T_val.reshape(-1, 1)

        u_exact = analytical_solution(X_flat * x_scale, T_flat * t_scale).cpu().numpy()
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=500)
    losses = []

    # Начинаем с оптимайзером Adam для быстрого начального приближения
    for epoch in range(epochs_adam):
        optimizer.zero_grad()
        loss, loss_pde, loss_ic, loss_bc = compute_loss(model, points_dtype, beta, x_scale, t_scale)
        loss.backward()

        if clipping_on:
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
        optimizer.step()
        scheduler.step(loss)
        losses.append(loss.item())

        if (epoch % epoch_log_adam == 0 or epoch == epochs_adam - 1) and not compare_loss:
            with torch.no_grad():
                u_pred = model(X_flat, T_flat).detach().cpu().numpy()
                mae = np.mean(np.abs(u_pred - u_exact))
                rmse = np.sqrt(np.mean((u_pred - u_exact)**2))
            print(f"[Epochs with Adam {epoch}] Loss: {loss.item():.2e} | MAE: {mae:.4e} | RMSE: {rmse:.4e}")
        if (epoch % epoch_log_adam == 0 or epoch == epochs_adam - 1) and compare_loss:
            with torch.no_grad():
                u_pred = model(X_flat, T_flat).detach().cpu().numpy()
                mae = np.mean(np.abs(u_pred - u_exact))
                rmse = np.sqrt(np.mean((u_pred - u_exact)**2))
            print(f"[Epochs with Adam {epoch}] Loss: {loss.item():.2e} | MAE: {mae:.4e} | RMSE: {rmse:.4e}")
            print(f"Loss IC: {loss_ic.item():.2e} | Loss BC: {loss_bc.item():.2e} | Loss PDE: {loss_pde.item():.2e}")

    # Переходим к L-BFGS для уменьшения потерь после начального приближения
    if epochs_lbfgs > 0:
        optimizer_lbfgs = torch.optim.LBFGS(model.parameters(), lr=1.0, max_iter=20, tolerance_change=1e-9, tolerance_grad=1e-5, history_size=100)
        for epoch in range(epochs_lbfgs):
            loss_components = {'pde': None, 'ic': None, 'bc': None}
            
            def closure():
                optimizer_lbfgs.zero_grad()
                loss, loss_pde, loss_ic, loss_bc = compute_loss(model, points_dtype, beta, x_scale, t_scale)
                
                loss_components['pde'] = loss_pde.detach().item()
                loss_components['ic'] = loss_ic.detach().item()
                loss_components['bc'] = loss_bc.detach().item()
                
                loss.backward()
                return loss

            loss = optimizer_lbfgs.step(closure)
            losses.append(loss.item())

            if (epoch % epoch_log_lbfgs == 0 or epoch == epochs_lbfgs - 1) and not compare_loss:
                with torch.no_grad():
                    u_pred = model(X_flat, T_flat).detach().cpu().numpy()
                    mae = np.mean(np.abs(u_pred - u_exact))
                    rmse = np.sqrt(np.mean((u_pred - u_exact)**2))
                print(f"[Epochs with L-BFGS {epoch}] Loss: {loss.item():.2e} | MAE: {mae:.4e} | RMSE: {rmse:.4e}")
            if (epoch % epoch_log_lbfgs == 0 or epoch == epochs_lbfgs - 1) and compare_loss:
                with torch.no_grad():
                    u_pred = model(X_flat, T_flat).detach().cpu().numpy()
                    mae = np.mean(np.abs(u_pred - u_exact))
                    rmse = np.sqrt(np.mean((u_pred - u_exact)**2))
                print(f"[Epochs with L-BFGS {epoch}] Loss: {loss.item():.2e} | MAE: {mae:.4e} | RMSE: {rmse:.4e}")
                print(f"Loss IC: {loss_components['ic']:.2e} | Loss BC: {loss_components['bc']:.2e} | Loss PDE: {loss_components['pde']:.2e}")

    return losses

# %%
def generate_points(n_res=20000, n_ic=500, n_bc=500):
    # Общие точки
    x_res = torch.rand(n_res, 1)
    t_res = torch.rand(n_res, 1)

    # Начальные точки
    x_ic = torch.rand(n_ic, 1)
    t_ic = torch.zeros(n_ic, 1)
    u_ic = analytical_solution(x_ic * x_scale, t_ic)

    # Граничные точки
    t_left = torch.rand(n_bc // 2, 1)
    t_right = torch.rand(n_bc // 2, 1)
    x_left = torch.zeros(n_bc // 2, 1)
    x_right = torch.ones(n_bc // 2, 1)

    return {'pde':(x_res, t_res), 'ic':(x_ic, t_ic, u_ic),
            'bc':(x_left, t_left, x_right, t_right)}

# %% [markdown]
# Функция для обучения модели с настраиваеми параметрами.

# %% [markdown]
# Генерация точек, подготовка к началу обучения.

# %%
points = generate_points(n_res=100000, n_ic=20000, n_bc=20000)

# %% [markdown]
# Обучение с использованием FP16.

# %% [markdown]
# Как мы видим, произишло переполнение при вычислениях где-то внутри модели. Попробуем уменьшить коэффициент $\beta$, чтобы упросить задачу, и запустим обучение с FP16 еще раз.

# %% [markdown]
# Как видим, FP16 для нашей архитектуры является неэффективным даже при низком leraning rate и маленьком $\beta$. Поэтому далее будем сравнивать между собой классический FP32 и FP64.
#
# Запуск обучения для FP32:

# %%
model_fp64 = PeriodicPINN()
start = time.time()
losses_fp64 = train(model_fp64, points, beta, torch.float64, device, x_scale, t_scale,
                    epochs_adam=2000,
                    epochs_lbfgs=4000,
                    lr=1e-3,
                    clipping_on=False,
                    epoch_log_adam=500,
                    epoch_log_lbfgs=100,
                    compare_loss=True)
end = time.time()
print(f"Время обучения: {end - start:.2f} секунд")
# Out:
# [Epochs with Adam 0] Loss: 4.48e-01 | MAE: 6.4020e-01 | RMSE: 7.1486e-01
# Loss IC: 6.07e-01 | Loss BC: 3.73e-02 | Loss PDE: 1.31e+01
# [Epochs with Adam 500] Loss: 3.72e-02 | MAE: 2.3339e-01 | RMSE: 3.0212e-01
# Loss IC: 2.35e-02 | Loss BC: 2.39e-02 | Loss PDE: 1.39e+00
# [Epochs with Adam 1000] Loss: 3.52e-02 | MAE: 2.3769e-01 | RMSE: 3.0229e-01
# Loss IC: 2.32e-02 | Loss BC: 2.09e-02 | Loss PDE: 1.35e+00
# [Epochs with Adam 1500] Loss: 3.45e-02 | MAE: 2.3458e-01 | RMSE: 3.0084e-01
# Loss IC: 2.28e-02 | Loss BC: 2.00e-02 | Loss PDE: 1.34e+00
# [Epochs with Adam 1999] Loss: 3.39e-02 | MAE: 2.2996e-01 | RMSE: 2.9935e-01
# Loss IC: 2.25e-02 | Loss BC: 1.92e-02 | Loss PDE: 1.33e+00
# [Epochs with L-BFGS 0] Loss: 3.39e-02 | MAE: 2.3166e-01 | RMSE: 2.9975e-01
# Loss IC: 2.26e-02 | Loss BC: 1.91e-02 | Loss PDE: 1.33e+00
# [Epochs with L-BFGS 100] Loss: 2.93e-02 | MAE: 2.0878e-01 | RMSE: 2.9777e-01
# Loss IC: 2.06e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.24e+00
# [Epochs with L-BFGS 200] Loss: 2.88e-02 | MAE: 2.0543e-01 | RMSE: 2.9814e-01
# Loss IC: 2.05e-02 | Loss BC: 1.34e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 300] Loss: 2.86e-02 | MAE: 2.0378e-01 | RMSE: 2.9820e-01
# Loss IC: 2.03e-02 | Loss BC: 1.32e-02 | Loss PDE: 1.21e+00
# [Epochs with L-BFGS 400] Loss: 2.84e-02 | MAE: 2.0343e-01 | RMSE: 2.9813e-01
# Loss IC: 2.02e-02 | Loss BC: 1.31e-02 | Loss PDE: 1.21e+00
# [Epochs with L-BFGS 500] Loss: 2.83e-02 | MAE: 2.0309e-01 | RMSE: 2.9820e-01
# Loss IC: 2.01e-02 | Loss BC: 1.29e-02 | Loss PDE: 1.21e+00
# [Epochs with L-BFGS 600] Loss: 2.82e-02 | MAE: 2.0271e-01 | RMSE: 2.9793e-01
# Loss IC: 2.00e-02 | Loss BC: 1.29e-02 | Loss PDE: 1.20e+00
# [Epochs with L-BFGS 700] Loss: 2.81e-02 | MAE: 2.0246e-01 | RMSE: 2.9790e-01
# Loss IC: 1.99e-02 | Loss BC: 1.27e-02 | Loss PDE: 1.20e+00
# [Epochs with L-BFGS 800] Loss: 2.80e-02 | MAE: 2.0200e-01 | RMSE: 2.9775e-01
# Loss IC: 1.98e-02 | Loss BC: 1.27e-02 | Loss PDE: 1.20e+00
# [Epochs with L-BFGS 900] Loss: 2.78e-02 | MAE: 2.0197e-01 | RMSE: 2.9794e-01
# Loss IC: 1.97e-02 | Loss BC: 1.26e-02 | Loss PDE: 1.20e+00
# [Epochs with L-BFGS 1000] Loss: 2.76e-02 | MAE: 2.0181e-01 | RMSE: 2.9767e-01
# Loss IC: 1.95e-02 | Loss BC: 1.25e-02 | Loss PDE: 1.19e+00
# [Epochs with L-BFGS 1100] Loss: 2.74e-02 | MAE: 2.0128e-01 | RMSE: 2.9723e-01
# Loss IC: 1.93e-02 | Loss BC: 1.23e-02 | Loss PDE: 1.19e+00
# [Epochs with L-BFGS 1200] Loss: 2.72e-02 | MAE: 2.0095e-01 | RMSE: 2.9660e-01
# Loss IC: 1.90e-02 | Loss BC: 1.22e-02 | Loss PDE: 1.18e+00
# [Epochs with L-BFGS 1300] Loss: 2.65e-02 | MAE: 1.9932e-01 | RMSE: 2.9474e-01
# Loss IC: 1.84e-02 | Loss BC: 1.18e-02 | Loss PDE: 1.16e+00
# [Epochs with L-BFGS 1400] Loss: 2.49e-02 | MAE: 1.9616e-01 | RMSE: 2.9148e-01
# Loss IC: 1.73e-02 | Loss BC: 1.11e-02 | Loss PDE: 1.09e+00
# [Epochs with L-BFGS 1500] Loss: 2.37e-02 | MAE: 1.9356e-01 | RMSE: 2.9073e-01
# Loss IC: 1.67e-02 | Loss BC: 1.07e-02 | Loss PDE: 1.03e+00
# [Epochs with L-BFGS 1600] Loss: 2.29e-02 | MAE: 1.9157e-01 | RMSE: 2.9026e-01
# Loss IC: 1.63e-02 | Loss BC: 1.04e-02 | Loss PDE: 9.80e-01
# [Epochs with L-BFGS 1700] Loss: 2.21e-02 | MAE: 1.9011e-01 | RMSE: 2.8967e-01
# Loss IC: 1.58e-02 | Loss BC: 1.01e-02 | Loss PDE: 9.40e-01
# [Epochs with L-BFGS 1800] Loss: 2.04e-02 | MAE: 1.8777e-01 | RMSE: 2.8817e-01
# Loss IC: 1.46e-02 | Loss BC: 9.35e-03 | Loss PDE: 8.57e-01
# [Epochs with L-BFGS 1900] Loss: 1.88e-02 | MAE: 1.8446e-01 | RMSE: 2.8762e-01
# Loss IC: 1.37e-02 | Loss BC: 8.91e-03 | Loss PDE: 7.72e-01
# [Epochs with L-BFGS 2000] Loss: 1.80e-02 | MAE: 1.8202e-01 | RMSE: 2.8712e-01
# Loss IC: 1.30e-02 | Loss BC: 9.08e-03 | Loss PDE: 7.08e-01
# [Epochs with L-BFGS 2100] Loss: 1.73e-02 | MAE: 1.8093e-01 | RMSE: 2.8717e-01
# Loss IC: 1.25e-02 | Loss BC: 8.84e-03 | Loss PDE: 6.76e-01
# [Epochs with L-BFGS 2200] Loss: 1.64e-02 | MAE: 1.7950e-01 | RMSE: 2.8630e-01
# Loss IC: 1.19e-02 | Loss BC: 8.26e-03 | Loss PDE: 6.46e-01
# [Epochs with L-BFGS 2300] Loss: 1.56e-02 | MAE: 1.7845e-01 | RMSE: 2.8628e-01
# Loss IC: 1.16e-02 | Loss BC: 7.83e-03 | Loss PDE: 6.07e-01
# [Epochs with L-BFGS 2400] Loss: 1.51e-02 | MAE: 1.7786e-01 | RMSE: 2.8621e-01
# Loss IC: 1.14e-02 | Loss BC: 7.48e-03 | Loss PDE: 5.80e-01
# [Epochs with L-BFGS 2500] Loss: 1.40e-02 | MAE: 1.7467e-01 | RMSE: 2.8460e-01
# Loss IC: 1.04e-02 | Loss BC: 6.83e-03 | Loss PDE: 5.56e-01
# [Epochs with L-BFGS 2600] Loss: 1.12e-02 | MAE: 1.6848e-01 | RMSE: 2.8429e-01
# Loss IC: 8.27e-03 | Loss BC: 5.75e-03 | Loss PDE: 4.27e-01
# [Epochs with L-BFGS 2700] Loss: 9.46e-03 | MAE: 1.6403e-01 | RMSE: 2.8576e-01
# Loss IC: 7.58e-03 | Loss BC: 5.18e-03 | Loss PDE: 3.16e-01
# [Epochs with L-BFGS 2800] Loss: 8.64e-03 | MAE: 1.6229e-01 | RMSE: 2.8647e-01
# Loss IC: 7.36e-03 | Loss BC: 4.91e-03 | Loss PDE: 2.58e-01
# [Epochs with L-BFGS 2900] Loss: 8.20e-03 | MAE: 1.6132e-01 | RMSE: 2.8653e-01
# Loss IC: 7.26e-03 | Loss BC: 4.76e-03 | Loss PDE: 2.27e-01
# [Epochs with L-BFGS 3000] Loss: 7.88e-03 | MAE: 1.6055e-01 | RMSE: 2.8718e-01
# Loss IC: 7.11e-03 | Loss BC: 4.72e-03 | Loss PDE: 2.04e-01
# [Epochs with L-BFGS 3100] Loss: 7.63e-03 | MAE: 1.5965e-01 | RMSE: 2.8710e-01
# Loss IC: 7.02e-03 | Loss BC: 4.60e-03 | Loss PDE: 1.89e-01
# [Epochs with L-BFGS 3200] Loss: 7.33e-03 | MAE: 1.5889e-01 | RMSE: 2.8757e-01
# Loss IC: 6.85e-03 | Loss BC: 4.43e-03 | Loss PDE: 1.76e-01
# [Epochs with L-BFGS 3300] Loss: 7.03e-03 | MAE: 1.5739e-01 | RMSE: 2.8792e-01
# Loss IC: 6.73e-03 | Loss BC: 4.27e-03 | Loss PDE: 1.59e-01
# [Epochs with L-BFGS 3400] Loss: 6.79e-03 | MAE: 1.5579e-01 | RMSE: 2.8863e-01
# Loss IC: 6.62e-03 | Loss BC: 4.22e-03 | Loss PDE: 1.44e-01
# [Epochs with L-BFGS 3500] Loss: 6.63e-03 | MAE: 1.5500e-01 | RMSE: 2.8930e-01
# Loss IC: 6.55e-03 | Loss BC: 4.22e-03 | Loss PDE: 1.31e-01
# [Epochs with L-BFGS 3600] Loss: 6.52e-03 | MAE: 1.5421e-01 | RMSE: 2.8955e-01
# Loss IC: 6.53e-03 | Loss BC: 4.20e-03 | Loss PDE: 1.22e-01
# [Epochs with L-BFGS 3700] Loss: 6.44e-03 | MAE: 1.5358e-01 | RMSE: 2.8987e-01
# Loss IC: 6.50e-03 | Loss BC: 4.18e-03 | Loss PDE: 1.16e-01
# [Epochs with L-BFGS 3800] Loss: 6.38e-03 | MAE: 1.5287e-01 | RMSE: 2.8969e-01
# Loss IC: 6.51e-03 | Loss BC: 4.14e-03 | Loss PDE: 1.12e-01
# [Epochs with L-BFGS 3900] Loss: 6.34e-03 | MAE: 1.5254e-01 | RMSE: 2.8978e-01
# Loss IC: 6.49e-03 | Loss BC: 4.15e-03 | Loss PDE: 1.08e-01
# [Epochs with L-BFGS 3999] Loss: 6.31e-03 | MAE: 1.5235e-01 | RMSE: 2.9011e-01
# Loss IC: 6.49e-03 | Loss BC: 4.14e-03 | Loss PDE: 1.05e-01
# Время обучения: 5505.09 секунд

# %%
#model_fp64_base = PINN()
#start = time.time()
#losses_fp64 = train(model_fp64_base, points, beta, torch.float64, device, x_scale, t_scale,
#                    epochs_adam=2000,
#                    epochs_lbfgs=4000,
#                    lr=1e-3,
#                    clipping_on=False,
#                    epoch_log_adam=500,
#                    epoch_log_lbfgs=100,
#                    compare_loss=True)
#end = time.time()
#print(f"Время обучения: {end - start:.2f} секунд")

# %%
#model_fp64_big = BIGPINN()
#start = time.time()
#losses_fp64 = train(model_fp64_big, points, beta, torch.float64, device, x_scale, t_scale,
#                    epochs_adam=2000,
#                    epochs_lbfgs=4000,
#                    lr=1e-3,
#                    clipping_on=False,
#                    epoch_log_adam=500,
#                    epoch_log_lbfgs=100,
#                    compare_loss=True)
#end = time.time()
#print(f"Время обучения: {end - start:.2f} секунд")

# %% [markdown]
# Запуск обучения для FP64:

# %%
model_fp32 = PeriodicPINN()
start = time.time()
losses_fp32 = train(model_fp32, points, beta, torch.float32, device, x_scale, t_scale,
                    epochs_adam=2000,
                    epochs_lbfgs=4000,
                    lr=1e-3,
                    clipping_on=False,
                    epoch_log_adam=500,
                    epoch_log_lbfgs=100,
                    compare_loss=True)
end = time.time()
print(f"Время обучения: {end - start:.2f} секунд")
# Out:
# [Epochs with Adam 0] Loss: 7.86e-01 | MAE: 6.3130e-01 | RMSE: 7.0274e-01
# Loss IC: 8.87e-01 | Loss BC: 2.92e-02 | Loss PDE: 3.36e+01
# [Epochs with Adam 500] Loss: 3.65e-02 | MAE: 2.3339e-01 | RMSE: 3.0033e-01
# Loss IC: 2.28e-02 | Loss BC: 2.26e-02 | Loss PDE: 1.42e+00
# [Epochs with Adam 1000] Loss: 3.52e-02 | MAE: 2.3616e-01 | RMSE: 3.0106e-01
# Loss IC: 2.29e-02 | Loss BC: 2.10e-02 | Loss PDE: 1.36e+00
# [Epochs with Adam 1500] Loss: 3.49e-02 | MAE: 2.3245e-01 | RMSE: 2.9986e-01
# Loss IC: 2.34e-02 | Loss BC: 1.94e-02 | Loss PDE: 1.38e+00
# [Epochs with Adam 1999] Loss: 3.40e-02 | MAE: 2.2946e-01 | RMSE: 2.9830e-01
# Loss IC: 2.22e-02 | Loss BC: 1.97e-02 | Loss PDE: 1.34e+00
# [Epochs with L-BFGS 0] Loss: 3.41e-02 | MAE: 2.3070e-01 | RMSE: 2.9868e-01
# Loss IC: 2.25e-02 | Loss BC: 1.90e-02 | Loss PDE: 1.36e+00
# [Epochs with L-BFGS 100] Loss: 2.92e-02 | MAE: 2.0693e-01 | RMSE: 2.9792e-01
# Loss IC: 2.06e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.23e+00
# [Epochs with L-BFGS 200] Loss: 2.87e-02 | MAE: 2.0487e-01 | RMSE: 2.9837e-01
# Loss IC: 2.04e-02 | Loss BC: 1.33e-02 | Loss PDE: 1.21e+00
# [Epochs with L-BFGS 300] Loss: 2.85e-02 | MAE: 2.0353e-01 | RMSE: 2.9829e-01
# Loss IC: 2.02e-02 | Loss BC: 1.32e-02 | Loss PDE: 1.21e+00
# [Epochs with L-BFGS 400] Loss: 2.83e-02 | MAE: 2.0295e-01 | RMSE: 2.9827e-01
# Loss IC: 2.01e-02 | Loss BC: 1.30e-02 | Loss PDE: 1.20e+00
# [Epochs with L-BFGS 500] Loss: 2.82e-02 | MAE: 2.0233e-01 | RMSE: 2.9828e-01
# Loss IC: 2.00e-02 | Loss BC: 1.29e-02 | Loss PDE: 1.20e+00
# [Epochs with L-BFGS 600] Loss: 2.80e-02 | MAE: 2.0229e-01 | RMSE: 2.9832e-01
# Loss IC: 1.97e-02 | Loss BC: 1.27e-02 | Loss PDE: 1.20e+00
# [Epochs with L-BFGS 700] Loss: 2.76e-02 | MAE: 2.0193e-01 | RMSE: 2.9824e-01
# Loss IC: 1.94e-02 | Loss BC: 1.25e-02 | Loss PDE: 1.19e+00
# [Epochs with L-BFGS 800] Loss: 2.70e-02 | MAE: 2.0143e-01 | RMSE: 2.9907e-01
# Loss IC: 1.90e-02 | Loss BC: 1.22e-02 | Loss PDE: 1.17e+00
# [Epochs with L-BFGS 900] Loss: 2.64e-02 | MAE: 2.0123e-01 | RMSE: 3.0059e-01
# Loss IC: 1.86e-02 | Loss BC: 1.19e-02 | Loss PDE: 1.14e+00
# [Epochs with L-BFGS 1000] Loss: 2.57e-02 | MAE: 2.0105e-01 | RMSE: 3.0148e-01
# Loss IC: 1.81e-02 | Loss BC: 1.17e-02 | Loss PDE: 1.11e+00
# [Epochs with L-BFGS 1100] Loss: 2.48e-02 | MAE: 2.0095e-01 | RMSE: 3.0364e-01
# Loss IC: 1.76e-02 | Loss BC: 1.12e-02 | Loss PDE: 1.06e+00
# [Epochs with L-BFGS 1200] Loss: 2.27e-02 | MAE: 2.0331e-01 | RMSE: 3.1141e-01
# Loss IC: 1.61e-02 | Loss BC: 1.01e-02 | Loss PDE: 9.76e-01
# [Epochs with L-BFGS 1300] Loss: 2.05e-02 | MAE: 2.0750e-01 | RMSE: 3.2517e-01
# Loss IC: 1.54e-02 | Loss BC: 9.57e-03 | Loss PDE: 8.21e-01
# [Epochs with L-BFGS 1400] Loss: 1.95e-02 | MAE: 2.0928e-01 | RMSE: 3.3229e-01
# Loss IC: 1.47e-02 | Loss BC: 9.23e-03 | Loss PDE: 7.67e-01
# [Epochs with L-BFGS 1500] Loss: 1.89e-02 | MAE: 2.1004e-01 | RMSE: 3.3594e-01
# Loss IC: 1.44e-02 | Loss BC: 9.07e-03 | Loss PDE: 7.32e-01
# [Epochs with L-BFGS 1600] Loss: 1.84e-02 | MAE: 2.1099e-01 | RMSE: 3.3954e-01
# Loss IC: 1.41e-02 | Loss BC: 8.83e-03 | Loss PDE: 7.06e-01
# [Epochs with L-BFGS 1700] Loss: 1.79e-02 | MAE: 2.1277e-01 | RMSE: 3.4396e-01
# Loss IC: 1.39e-02 | Loss BC: 8.65e-03 | Loss PDE: 6.81e-01
# [Epochs with L-BFGS 1800] Loss: 1.75e-02 | MAE: 2.1428e-01 | RMSE: 3.4791e-01
# Loss IC: 1.37e-02 | Loss BC: 8.46e-03 | Loss PDE: 6.57e-01
# [Epochs with L-BFGS 1900] Loss: 1.72e-02 | MAE: 2.1547e-01 | RMSE: 3.5098e-01
# Loss IC: 1.36e-02 | Loss BC: 8.39e-03 | Loss PDE: 6.38e-01
# [Epochs with L-BFGS 2000] Loss: 1.70e-02 | MAE: 2.1537e-01 | RMSE: 3.5179e-01
# Loss IC: 1.35e-02 | Loss BC: 8.32e-03 | Loss PDE: 6.30e-01
# [Epochs with L-BFGS 2100] Loss: 1.69e-02 | MAE: 2.1553e-01 | RMSE: 3.5298e-01
# Loss IC: 1.34e-02 | Loss BC: 8.26e-03 | Loss PDE: 6.23e-01
# [Epochs with L-BFGS 2200] Loss: 1.67e-02 | MAE: 2.1591e-01 | RMSE: 3.5364e-01
# Loss IC: 1.32e-02 | Loss BC: 8.19e-03 | Loss PDE: 6.20e-01
# [Epochs with L-BFGS 2300] Loss: 1.65e-02 | MAE: 2.1652e-01 | RMSE: 3.5476e-01
# Loss IC: 1.30e-02 | Loss BC: 8.06e-03 | Loss PDE: 6.14e-01
# [Epochs with L-BFGS 2400] Loss: 1.60e-02 | MAE: 2.1730e-01 | RMSE: 3.5711e-01
# Loss IC: 1.27e-02 | Loss BC: 7.78e-03 | Loss PDE: 5.92e-01
# [Epochs with L-BFGS 2500] Loss: 1.54e-02 | MAE: 2.1902e-01 | RMSE: 3.6053e-01
# Loss IC: 1.23e-02 | Loss BC: 7.48e-03 | Loss PDE: 5.61e-01
# [Epochs with L-BFGS 2600] Loss: 1.46e-02 | MAE: 2.1803e-01 | RMSE: 3.6046e-01
# Loss IC: 1.16e-02 | Loss BC: 7.24e-03 | Loss PDE: 5.34e-01
# [Epochs with L-BFGS 2700] Loss: 1.39e-02 | MAE: 2.1774e-01 | RMSE: 3.6213e-01
# Loss IC: 1.11e-02 | Loss BC: 6.90e-03 | Loss PDE: 4.98e-01
# [Epochs with L-BFGS 2800] Loss: 1.32e-02 | MAE: 2.1822e-01 | RMSE: 3.6346e-01
# Loss IC: 1.08e-02 | Loss BC: 6.51e-03 | Loss PDE: 4.64e-01
# [Epochs with L-BFGS 2900] Loss: 1.24e-02 | MAE: 2.1885e-01 | RMSE: 3.6436e-01
# Loss IC: 1.02e-02 | Loss BC: 6.05e-03 | Loss PDE: 4.37e-01
# [Epochs with L-BFGS 3000] Loss: 1.06e-02 | MAE: 2.2082e-01 | RMSE: 3.6249e-01
# Loss IC: 8.31e-03 | Loss BC: 4.91e-03 | Loss PDE: 4.07e-01
# [Epochs with L-BFGS 3100] Loss: 7.54e-03 | MAE: 2.2742e-01 | RMSE: 3.5817e-01
# Loss IC: 6.43e-03 | Loss BC: 2.74e-03 | Loss PDE: 3.01e-01
# [Epochs with L-BFGS 3200] Loss: 6.19e-03 | MAE: 2.2863e-01 | RMSE: 3.5988e-01
# Loss IC: 5.25e-03 | Loss BC: 2.49e-03 | Loss PDE: 2.37e-01
# [Epochs with L-BFGS 3300] Loss: 5.36e-03 | MAE: 2.3002e-01 | RMSE: 3.6190e-01
# Loss IC: 4.51e-03 | Loss BC: 2.31e-03 | Loss PDE: 2.00e-01
# [Epochs with L-BFGS 3400] Loss: 4.89e-03 | MAE: 2.3019e-01 | RMSE: 3.6223e-01
# Loss IC: 4.12e-03 | Loss BC: 2.21e-03 | Loss PDE: 1.77e-01
# [Epochs with L-BFGS 3500] Loss: 4.59e-03 | MAE: 2.3032e-01 | RMSE: 3.6248e-01
# Loss IC: 3.91e-03 | Loss BC: 2.13e-03 | Loss PDE: 1.62e-01
# [Epochs with L-BFGS 3600] Loss: 4.40e-03 | MAE: 2.3092e-01 | RMSE: 3.6329e-01
# Loss IC: 3.78e-03 | Loss BC: 2.08e-03 | Loss PDE: 1.51e-01
# [Epochs with L-BFGS 3700] Loss: 4.24e-03 | MAE: 2.3106e-01 | RMSE: 3.6344e-01
# Loss IC: 3.70e-03 | Loss BC: 2.02e-03 | Loss PDE: 1.42e-01
# [Epochs with L-BFGS 3800] Loss: 4.09e-03 | MAE: 2.3151e-01 | RMSE: 3.6384e-01
# Loss IC: 3.65e-03 | Loss BC: 1.98e-03 | Loss PDE: 1.48e-01
# [Epochs with L-BFGS 3900] Loss: 3.97e-03 | MAE: 2.3187e-01 | RMSE: 3.6403e-01
# Loss IC: 3.61e-03 | Loss BC: 1.85e-03 | Loss PDE: 1.28e-01
# [Epochs with L-BFGS 3999] Loss: nan | MAE: nan | RMSE: nan
# Loss IC: nan | Loss BC: nan | Loss PDE: nan
# Время обучения: 3513.92 секунд

# %%
model_fp32_best = PeriodicPINN()
start = time.time()
losses_fp32_best = train(model_fp32_best, points, beta, torch.float32, device, x_scale, t_scale,
                    epochs_adam=2000,
                    epochs_lbfgs=1100,
                    lr=1e-3,
                    clipping_on=False,
                    epoch_log_adam=500,
                    epoch_log_lbfgs=100,
                    compare_loss=True)
end = time.time()
print(f"Время обучения: {end - start:.2f} секунд")
# Out:
# [Epochs with Adam 0] Loss: 5.34e-01 | MAE: 6.4853e-01 | RMSE: 7.2294e-01
# Loss IC: 5.38e-01 | Loss BC: 6.17e-02 | Loss PDE: 2.40e+01
# [Epochs with Adam 500] Loss: 3.68e-02 | MAE: 2.3633e-01 | RMSE: 3.0265e-01
# Loss IC: 2.20e-02 | Loss BC: 2.42e-02 | Loss PDE: 1.41e+00
# [Epochs with Adam 1000] Loss: 3.52e-02 | MAE: 2.3628e-01 | RMSE: 3.0113e-01
# Loss IC: 2.29e-02 | Loss BC: 2.09e-02 | Loss PDE: 1.37e+00
# [Epochs with Adam 1500] Loss: 3.47e-02 | MAE: 2.3419e-01 | RMSE: 2.9975e-01
# Loss IC: 2.27e-02 | Loss BC: 2.03e-02 | Loss PDE: 1.36e+00
# [Epochs with Adam 1999] Loss: 3.42e-02 | MAE: 2.3297e-01 | RMSE: 2.9986e-01
# Loss IC: 2.26e-02 | Loss BC: 1.96e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 0] Loss: 3.42e-02 | MAE: 2.3299e-01 | RMSE: 2.9987e-01
# Loss IC: 2.26e-02 | Loss BC: 1.96e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 100] Loss: 3.42e-02 | MAE: 2.3303e-01 | RMSE: 2.9989e-01
# Loss IC: 2.26e-02 | Loss BC: 1.95e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 200] Loss: 3.42e-02 | MAE: 2.3302e-01 | RMSE: 2.9992e-01
# Loss IC: 2.26e-02 | Loss BC: 1.95e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 300] Loss: 3.42e-02 | MAE: 2.3299e-01 | RMSE: 2.9993e-01
# Loss IC: 2.26e-02 | Loss BC: 1.95e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 400] Loss: 3.41e-02 | MAE: 2.3294e-01 | RMSE: 2.9994e-01
# Loss IC: 2.26e-02 | Loss BC: 1.94e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 500] Loss: 3.41e-02 | MAE: 2.3288e-01 | RMSE: 2.9995e-01
# Loss IC: 2.26e-02 | Loss BC: 1.94e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 600] Loss: 3.41e-02 | MAE: 2.3281e-01 | RMSE: 2.9994e-01
# Loss IC: 2.26e-02 | Loss BC: 1.94e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 700] Loss: 3.41e-02 | MAE: 2.3273e-01 | RMSE: 2.9994e-01
# Loss IC: 2.25e-02 | Loss BC: 1.94e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 800] Loss: 3.41e-02 | MAE: 2.3266e-01 | RMSE: 2.9993e-01
# Loss IC: 2.25e-02 | Loss BC: 1.94e-02 | Loss PDE: 1.34e+00
# [Epochs with L-BFGS 900] Loss: 3.40e-02 | MAE: 2.3258e-01 | RMSE: 2.9993e-01
# Loss IC: 2.25e-02 | Loss BC: 1.93e-02 | Loss PDE: 1.34e+00
# [Epochs with L-BFGS 1000] Loss: 3.40e-02 | MAE: 2.3249e-01 | RMSE: 2.9992e-01
# Loss IC: 2.25e-02 | Loss BC: 1.93e-02 | Loss PDE: 1.34e+00
# [Epochs with L-BFGS 1099] Loss: 3.40e-02 | MAE: 2.3241e-01 | RMSE: 2.9991e-01
# Loss IC: 2.25e-02 | Loss BC: 1.93e-02 | Loss PDE: 1.34e+00
# Время обучения: 794.78 секунд

# %%
model_fp16 = PINN()
losses_fp16 = train(model_fp16, points, beta, torch.float16, device, x_scale, t_scale, epochs_adam=50, epochs_lbfgs=0,
                    lr=1e-7, clipping_on=True, epoch_log_adam=10, epoch_log_lbfgs=0, compare_loss=False)
# Out:
# [Epochs with Adam 0] Loss: 2.42e-01 | MAE: nan | RMSE: nan
# [Epochs with Adam 10] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 20] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 30] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 40] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 49] Loss: nan | MAE: nan | RMSE: nan

# %%
model_fp16_easy = PINN()
losses_fp16_easy = train(model_fp16_easy, points, 5, torch.float16, device, x_scale, t_scale, epochs_adam=500, epochs_lbfgs=0,
                         lr=1e-7, clipping_on=True, epoch_log_adam=50, epoch_log_lbfgs=0, compare_loss=False)
# Out:
# [Epochs with Adam 0] Loss: 2.50e-01 | MAE: nan | RMSE: nan
# [Epochs with Adam 50] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 100] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 150] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 200] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 250] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 300] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 350] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 400] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 450] Loss: nan | MAE: nan | RMSE: nan
# [Epochs with Adam 499] Loss: nan | MAE: nan | RMSE: nan

# %%
plt.figure(figsize=(15, 6))

plt.semilogy(losses_fp64, label='FP64', linewidth=2, color='blue')
plt.semilogy(losses_fp32[:-100], label='FP32', linewidth=2, color='red')
plt.semilogy(losses_fp16, label='FP16', linewidth=2, color='green')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Изменение функции потерь со временем')
plt.legend()
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))

plt.semilogy(losses_fp64, label='FP64', linewidth=2, color='blue')
plt.semilogy(losses_fp32_best, label='FP32', linewidth=2, color='red')
plt.semilogy(losses_fp16, label='FP16', linewidth=2, color='green')
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Изменение функции потерь со временем')
plt.legend()
plt.grid(True, alpha=0.3, linestyle='--')
plt.tight_layout()
plt.show()

def plot_results(model, dtype, name, beta, x_min, x_max, t_min, t_max, n_x=150, n_t=80):
    # Создание сетки
    x_vals = torch.linspace(x_min, x_max, n_x).reshape(-1, 1)
    t_vals = torch.linspace(t_min, t_max, n_t).reshape(-1, 1)
    X, T = torch.meshgrid(x_vals.squeeze(), t_vals.squeeze(), indexing='ij')
    X_flat = X.reshape(-1, 1)
    T_flat = T.reshape(-1, 1)

    X_norm = X_flat / x_scale
    T_norm = T_flat / t_scale

    # Теоретическое решение
    u_exact = analytical_solution(X_flat, T_flat).numpy().reshape(n_x, n_t)

    # Предсказания модели
    model = model.to(dtype).cpu()
    with torch.no_grad():
        u_pred = model(X_norm.to(dtype), T_norm.to(dtype)).cpu().numpy().reshape(n_x, n_t)

    error = np.abs(u_pred - u_exact)

    # Графики
    
    fig, axes = plt.subplots(1, 3, figsize=(15, 4.5))

    с1 = axes[0].imshow(u_exact, extent=[t_min, t_max, x_min, x_max],
                         origin='lower', aspect='auto', cmap='viridis')

    axes[0].set_xlabel('t')
    axes[0].set_ylabel('x')
    axes[0].set_title('Точное решение')
    plt.colorbar(с1, ax=axes[0], label='u(x,t)')

    с2 = axes[1].imshow(u_pred, extent=[t_min, t_max, x_min, x_max],
                         origin='lower', aspect='auto', cmap='viridis')

    axes[1].set_xlabel('t')
    axes[1].set_ylabel('x')
    axes[1].set_title(f'Предсказания {name}')
    plt.colorbar(с2, ax=axes[1], label='u(x,t)')

    с3 = axes[2].imshow(error, extent=[t_min, t_max, x_min, x_max],
                         origin='lower', aspect='auto', cmap='inferno')
    axes[2].set_xlabel('t')
    axes[2].set_ylabel('x')
    axes[2].set_title(f'Абсолютная ошибка')
    plt.colorbar(с3, ax=axes[2], label='|u_pred - u_exact|')

    plt.suptitle(f'Решения для {name}', fontsize=14, y=1.02)
    plt.tight_layout()
    plt.show()

    # Возврат ошибок для таблицы
    mae = np.mean(error)
    rmse = np.sqrt(np.mean(error**2))
    return mae, rmse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_711/4272478088.py in <cell line: 0>()
#       2
#       3 plt.semilogy(losses_fp64, label='FP64', linewidth=2, color='blue')
# ----> 4 plt.semilogy(losses_fp32_best, label='FP32', linewidth=2, color='red')
#       5 plt.semilogy(losses_fp16, label='FP16', linewidth=2, color='green')
#       6 plt.xlabel('Epoch')
#
# NameError: name 'losses_fp32_best' is not defined

# %%
metrics = {}

# Построение графиков

print("Обучение с FP64")
mae, rmse = plot_results(model_fp64, torch.float64, 'FP64', beta, x_min, x_max, t_min, t_max)
metrics['FP64'] = (mae, rmse)

print("Обучение с FP32")
mae, rmse = plot_results(model_fp32_best, torch.float32, 'FP32', beta, x_min, x_max, t_min, t_max)
metrics['FP32'] = (mae, rmse)

#Таблица MAE и RMSE

metrics_df = pd.DataFrame(metrics, index=['MAE', 'RMSE']).T
print("Сравнение MAE и RMSE для разных типов данных")
print(metrics_df.round(6))
# Out:
# Обучение с FP64
# Обучение с FP32
# Сравнение MAE и RMSE для разных типов данных
#            MAE      RMSE
# FP64  0.151497  0.289094
# FP32  0.231882  0.299285

# %%
def compute_loss_l2(model, points, beta, x_scale, t_scale, weights=(1.0, 50.0, 50.0), l2_lambda=0.0):
    w_pde, w_ic, w_bc = weights
    x_res, t_res = points['pde']

    # PDE residual loss - невязка дифференциального уравнения в частных производных
    loss_pde = torch.mean(pde_residual(model, x_res, t_res, beta, x_scale, t_scale)**2)

    # IC loss - потери, связанные с начальным условием
    x_ic, t_ic, u_ic = points['ic']
    u_ic_pred = model(x_ic, t_ic)
    loss_ic = torch.mean((u_ic_pred - u_ic)**2)

    # BC loss - потери, связанные с граничным условием
    x_l, t_l, x_r, t_r = points['bc']
    u_l = model(x_l, t_l)
    u_r = model(x_r, t_r)
    loss_bc = torch.mean((u_l - u_r)**2)

    total = w_pde * loss_pde + w_ic * loss_ic + w_bc * loss_bc
    total /= (w_pde + w_ic + w_bc)
    if l2_lambda > 0:
        l2_reg = sum(p.norm(2).pow(2) for p in model.parameters())
        total = total + l2_lambda * l2_reg
    return total, loss_pde, loss_ic, loss_bc

# %%
def train_l2(model, points, beta, dtype, device, x_scale, t_scale, epochs_adam=1000, epochs_lbfgs=0,
          lr=1e-3, clipping_on=False, epoch_log_adam=500, epoch_log_lbfgs=100, compare_loss=False):
    model = model.to(dtype).to(device)
    points_dtype = {}
    points_dtype['pde'] = (points['pde'][0].to(dtype).to(device), points['pde'][1].to(dtype).to(device))
    points_dtype['ic'] = (points['ic'][0].to(dtype).to(device), points['ic'][1].to(dtype).to(device), points['ic'][2].to(dtype).to(device))
    points_dtype['bc'] = (points['bc'][0].to(dtype).to(device), points['bc'][1].to(dtype).to(device),
                          points['bc'][2].to(dtype).to(device), points['bc'][3].to(dtype).to(device))

    with torch.no_grad():
        x_val = torch.linspace(0, 1, 100).reshape(-1, 1).to(dtype).to(device)
        t_val = torch.linspace(0, 1, 100).reshape(-1, 1).to(dtype).to(device)
        X_val, T_val = torch.meshgrid(x_val.squeeze(), t_val.squeeze(), indexing='ij')
        X_flat = X_val.reshape(-1, 1)
        T_flat = T_val.reshape(-1, 1)

        u_exact = analytical_solution(X_flat * x_scale, T_flat * t_scale).cpu().numpy()
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=500)
    losses = []

    # Начинаем с оптимайзером Adam для быстрого начального приближения
    for epoch in range(epochs_adam):
        optimizer.zero_grad()
        loss, loss_pde, loss_ic, loss_bc = compute_loss_l2(model, points_dtype, beta, x_scale, t_scale, l2_lambda=1e-5)
        loss.backward()

        if clipping_on:
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
        optimizer.step()
        scheduler.step(loss)
        losses.append(loss.item())

        if (epoch % epoch_log_adam == 0 or epoch == epochs_adam - 1) and not compare_loss:
            with torch.no_grad():
                u_pred = model(X_flat, T_flat).detach().cpu().numpy()
                mae = np.mean(np.abs(u_pred - u_exact))
                rmse = np.sqrt(np.mean((u_pred - u_exact)**2))
            print(f"[Epochs with Adam {epoch}] Loss: {loss.item():.2e} | MAE: {mae:.4e} | RMSE: {rmse:.4e}")
        if (epoch % epoch_log_adam == 0 or epoch == epochs_adam - 1) and compare_loss:
            with torch.no_grad():
                u_pred = model(X_flat, T_flat).detach().cpu().numpy()
                mae = np.mean(np.abs(u_pred - u_exact))
                rmse = np.sqrt(np.mean((u_pred - u_exact)**2))
            print(f"[Epochs with Adam {epoch}] Loss: {loss.item():.2e} | MAE: {mae:.4e} | RMSE: {rmse:.4e}")
            print(f"Loss IC: {loss_ic.item():.2e} | Loss BC: {loss_bc.item():.2e} | Loss PDE: {loss_pde.item():.2e}")

    # Переходим к L-BFGS для уменьшения потерь после начального приближения
    if epochs_lbfgs > 0:
        optimizer_lbfgs = torch.optim.LBFGS(model.parameters(), lr=1.0, max_iter=20, tolerance_change=1e-9, tolerance_grad=1e-5, history_size=100)
        for epoch in range(epochs_lbfgs):
            loss_components = {'pde': None, 'ic': None, 'bc': None}
            
            def closure():
                optimizer_lbfgs.zero_grad()
                loss, loss_pde, loss_ic, loss_bc = compute_loss_l2(model, points_dtype, beta, x_scale, t_scale, l2_lambda=1e-5)
                
                loss_components['pde'] = loss_pde.detach().item()
                loss_components['ic'] = loss_ic.detach().item()
                loss_components['bc'] = loss_bc.detach().item()
                
                loss.backward()
                return loss

            loss = optimizer_lbfgs.step(closure)
            losses.append(loss.item())

            if (epoch % epoch_log_lbfgs == 0 or epoch == epochs_lbfgs - 1) and not compare_loss:
                with torch.no_grad():
                    u_pred = model(X_flat, T_flat).detach().cpu().numpy()
                    mae = np.mean(np.abs(u_pred - u_exact))
                    rmse = np.sqrt(np.mean((u_pred - u_exact)**2))
                print(f"[Epochs with L-BFGS {epoch}] Loss: {loss.item():.2e} | MAE: {mae:.4e} | RMSE: {rmse:.4e}")
            if (epoch % epoch_log_lbfgs == 0 or epoch == epochs_lbfgs - 1) and compare_loss:
                with torch.no_grad():
                    u_pred = model(X_flat, T_flat).detach().cpu().numpy()
                    mae = np.mean(np.abs(u_pred - u_exact))
                    rmse = np.sqrt(np.mean((u_pred - u_exact)**2))
                print(f"[Epochs with L-BFGS {epoch}] Loss: {loss.item():.2e} | MAE: {mae:.4e} | RMSE: {rmse:.4e}")
                print(f"Loss IC: {loss_components['ic']:.2e} | Loss BC: {loss_components['bc']:.2e} | Loss PDE: {loss_components['pde']:.2e}")

    return losses

# %%
model_fp64_l2 = PeriodicPINN()
start = time.time()
losses_fp64 = train_l2(model_fp64_l2, points, beta, torch.float64, device, x_scale, t_scale,
                    epochs_adam=2000,
                    epochs_lbfgs=2000,
                    lr=1e-3,
                    clipping_on=False,
                    epoch_log_adam=500,
                    epoch_log_lbfgs=100,
                    compare_loss=True)
end = time.time()
print(f"Время обучения: {end - start:.2f} секунд")
# Out:
# [Epochs with Adam 0] Loss: 1.61e+00 | MAE: 6.1421e-01 | RMSE: 7.0332e-01
# Loss IC: 1.36e+00 | Loss BC: 1.17e-01 | Loss PDE: 8.79e+01
# [Epochs with Adam 500] Loss: 4.19e-02 | MAE: 2.3498e-01 | RMSE: 3.0617e-01
# Loss IC: 2.26e-02 | Loss BC: 2.66e-02 | Loss PDE: 1.47e+00
# [Epochs with Adam 1000] Loss: 3.88e-02 | MAE: 2.3795e-01 | RMSE: 3.0282e-01
# Loss IC: 2.27e-02 | Loss BC: 2.19e-02 | Loss PDE: 1.38e+00
# [Epochs with Adam 1500] Loss: 3.86e-02 | MAE: 2.3659e-01 | RMSE: 3.0156e-01
# Loss IC: 2.35e-02 | Loss BC: 2.00e-02 | Loss PDE: 1.42e+00
# [Epochs with Adam 1999] Loss: 3.76e-02 | MAE: 2.3461e-01 | RMSE: 3.0079e-01
# Loss IC: 2.25e-02 | Loss BC: 2.04e-02 | Loss PDE: 1.35e+00
# [Epochs with L-BFGS 0] Loss: 3.76e-02 | MAE: 2.3593e-01 | RMSE: 3.0052e-01
# Loss IC: 2.27e-02 | Loss BC: 1.96e-02 | Loss PDE: 1.37e+00
# [Epochs with L-BFGS 100] Loss: 3.14e-02 | MAE: 2.1017e-01 | RMSE: 2.9786e-01
# Loss IC: 2.09e-02 | Loss BC: 1.43e-02 | Loss PDE: 1.24e+00
# [Epochs with L-BFGS 200] Loss: 3.08e-02 | MAE: 2.0977e-01 | RMSE: 2.9809e-01
# Loss IC: 2.08e-02 | Loss BC: 1.39e-02 | Loss PDE: 1.23e+00
# [Epochs with L-BFGS 300] Loss: 3.07e-02 | MAE: 2.0870e-01 | RMSE: 2.9810e-01
# Loss IC: 2.07e-02 | Loss BC: 1.38e-02 | Loss PDE: 1.23e+00
# [Epochs with L-BFGS 400] Loss: 3.06e-02 | MAE: 2.0814e-01 | RMSE: 2.9806e-01
# Loss IC: 2.07e-02 | Loss BC: 1.38e-02 | Loss PDE: 1.23e+00
# [Epochs with L-BFGS 500] Loss: 3.06e-02 | MAE: 2.0813e-01 | RMSE: 2.9806e-01
# Loss IC: 2.07e-02 | Loss BC: 1.38e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 600] Loss: 3.05e-02 | MAE: 2.0792e-01 | RMSE: 2.9808e-01
# Loss IC: 2.07e-02 | Loss BC: 1.38e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 700] Loss: 3.05e-02 | MAE: 2.0786e-01 | RMSE: 2.9809e-01
# Loss IC: 2.07e-02 | Loss BC: 1.38e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 800] Loss: 3.05e-02 | MAE: 2.0776e-01 | RMSE: 2.9806e-01
# Loss IC: 2.06e-02 | Loss BC: 1.38e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 900] Loss: 3.05e-02 | MAE: 2.0776e-01 | RMSE: 2.9810e-01
# Loss IC: 2.07e-02 | Loss BC: 1.38e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1000] Loss: 3.05e-02 | MAE: 2.0764e-01 | RMSE: 2.9810e-01
# Loss IC: 2.06e-02 | Loss BC: 1.38e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1100] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9805e-01
# Loss IC: 2.06e-02 | Loss BC: 1.38e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1200] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9807e-01
# Loss IC: 2.07e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1300] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9807e-01
# Loss IC: 2.07e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1400] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9807e-01
# Loss IC: 2.07e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1500] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9807e-01
# Loss IC: 2.07e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1600] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9807e-01
# Loss IC: 2.07e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1700] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9807e-01
# Loss IC: 2.07e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1800] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9807e-01
# Loss IC: 2.07e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1900] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9807e-01
# Loss IC: 2.07e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.22e+00
# [Epochs with L-BFGS 1999] Loss: 3.05e-02 | MAE: 2.0755e-01 | RMSE: 2.9807e-01
# Loss IC: 2.07e-02 | Loss BC: 1.37e-02 | Loss PDE: 1.22e+00
# Время обучения: 1631.85 секунд

# %%
print("Обучение с FP64 и L2 регуляризацией")
mae, rmse = plot_results(model_fp64_l2, torch.float64, 'FP64', beta, x_min, x_max, t_min, t_max)
print(f'MAE" {mae}, RMSE {rmse}')
# Out:
# Обучение с FP64 и L2 регуляризацией
# MAE" 0.2069324306494224, RMSE 0.29736443385195754
